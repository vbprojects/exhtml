// %%
const fs = require('node:fs');

// %%
var tag_names = new Set(["!--...--", "!DOCTYPE", "a", "abbr", "acronym", "address", "applet", "area", "article", "aside", "audio", "b", "base", "basefont", "bdi", "bdo", "big", "blockquote", "body", "br", "button", "canvas", "caption", "center", "cite", "code", "col", "colgroup", "data", "datalist", "dd", "del", "details", "dfn", "dialog", "dir", "div", "dl", "dt", "em", "embed", "fieldset", "figcaption", "figure", "font", "footer", "form", "frame", "frameset", "h1", "h2", "h3", "h4", "h5", "h6", "head", "header", "hgroup", "hr", "html", "i", "iframe", "img", "input", "ins", "kbd", "label", "legend", "li", "link", "main", "map", "mark", "menu", "meta", "meter", "nav", "noframes", "noscript", "object", "ol", "optgroup", "option", "output", "p", "param", "picture", "pre", "progress", "q", "rp", "rt", "ruby", "s", "samp", "script", "search", "section", "select", "small", "source", "span", "strike", "strong", "style", "sub", "summary", "sup", "svg", "table", "tbody", "td", "template", "textarea", "tfoot", "th", "thead", "time", "title", "tr", "track", "tt", "u", "ul", "var", "video", "wbr"])

var global_state = {};
var macros = {};

// %%
function get_macro(name){}
function set_macro(name, value){}
function get_var(name){}

// %%
class element{
    constructor(){
        this.children = [];
        this.text = "";
        this.parent = null;
    }
    forward(){return "";}
    backward(){return "";}
    children;
    get_children(){return this.children;}
    text;
    get_text(){return this.text;}
    parent;
    get_parent(){return this.parent;}
}



function process_line(line){
    line = line.trimStart();
    line = line.replaceAll("\r", "");
    line = line.replaceAll("\n", "");
    tokens = line.split(" ");
    is_tag = false;
    is_self_closing = false;
    maybe_tag = tokens[0]

    if(maybe_tag[0] == "<"){
        maybe_tag = maybe_tag.slice(1);
        is_tag = true;
    }
    if(maybe_tag[-1] == ">"){
        maybe_tag = maybe_tag.slice(0, -1);
    }
    if(tag_names.has(maybe_tag)){
        is_tag = true;
    }

    if(is_tag){
        return new tag_element(tokens, maybe_tag, is_self_closing, line);
    }
    // if(maybe_tag == ":set"){
    //     return new macro_setter(line);
    // }
    if(maybe_tag == ":macro"){
        return new macro_setter(tokens);
    }
    if(maybe_tag[0] == "!"){
        return new macro_element(maybe_tag);
    }
    return new text_element(line, maybe_tag == "raw");

}

class text_element extends element{
    text;
    constructor(line, starts_with_raw){
        super();
        if (starts_with_raw){
            this.text = line.trimStart().slice(4);
        }
        else{
            this.text = line.trimStart();
        }
    }
    forward(){
        return this.text;
    }
    backward(){
        return "\n";
    }
    get_text(){
        return this.text;
    }
    get_children(){
        return [];
    }
}

class tag_element extends element{ 
    tag;
    self_closing;
    attributes;
    classes;
    id;
    tokens;
    line;
    constructor(tokens, tag, is_self_closing, line){
        super();
        this.id = "";
        this.classes = [];
        this.attributes = [];
        this.tag = tag;
        this.self_closing = is_self_closing;
        this.tokens = tokens;
        this.line = line;
    }
    forward(){
        
        for(let i = 1; i < this.tokens.length; i++){
            var token = this.tokens[i];
            if(token[0] == "@"){
                token = global_state[token].text;
            }
            if(token.includes("=")){
                this.attributes.push(token);
            }else if(token[0] == "#"){
                this.id += tokens[i].slice(1);
            }else if(token == "|"){
                let post_tag = this.line.slice(this.line.indexOf("|") + 1).
                trimStart();
                var maybe_macros = post_tag.split("@")
                var maybe_macros_names = maybe_macros.map((x) => x.split(" "))
                if(maybe_macros.length == 1){this.text = post_tag;break;}
                var li;
                var ti;
                for(li in maybe_macros_names){
                    for(ti in maybe_macros_names[li]){
                        if(("@" + maybe_macros_names[li][ti]) in global_state){
                            maybe_macros_names[li][ti] = "@" + global_state["@" + maybe_macros_names[li][ti]].text;
                        }
                    }
                }
                this.text = maybe_macros_names.map((x) => x.join(" ")).join("@").replaceAll("@@", "")
                break;
            }else{
                this.classes.push(token);
            }
        }

        let result = "<" + this.tag;
        if(this.id != ""){
            result += " id=\"" + this.id + "\"";
        }
        if(this.classes.length > 0){
            result += " class=\"" + this.classes.join(" ") + "\"";
        }
        if(this.attributes.length > 0){
            result += " " + this.attributes.join(" ");
        }
        if(this.self_closing){
            result += " />";
        }else{
            result += ">";
        }
        result += this.text;
        return result;
    }
    backward(){
        if (this.self_closing){
            return "\n";
        }
        return "</" + this.tag + ">\n";
    }
    get_text(){
        return this.text;
    }
    get_children(){
        return this.children;
    }
}

class macro_setter extends element{
    name;
    constructor(tokens){
        super();
        this.name = ""
        if(tokens.length > 1)
            this.name = tokens[1];
    }
    forward(){
        macros[this.name] = this.children;
        return "";
    }
    backward(){
        return "";
    }
    get_text(){
        return "";
    }
    get_children(){
        return [];
    }
}

class macro_element extends element{
    constructor(name){
        super();
        this.name = name;
    }
    forward(){
        for(let i = 0; i < this.children.length; i++){
            global_state["@" + i] = this.children[i];
        }
        return "";
    }
    backward(){
        return "";
    }
    get_text(){
        return "";
    }
    get_children(){
        return macros[this.name];
    }
}
class mlstate{
    variables;
    macros;
    constructor(){
        this.variables = {};
        this.macros = {};
    }
}

// %%
input = fs.readFileSync("index2.vpml", "utf-8").toString().split('\n');
// Out:
// [
//   '#define li_tag text-sm md:text-base \r',
//   'head\r',
//   '    raw <meta name="viewport" content="width=device-width, initial-scale=1.0"/>\r',
//   '    raw <link href="https://cdn.jsdelivr.net/npm/daisyui@4.10.1/dist/full.min.css" rel="stylesheet" type="text/css"/>\r',
//   '    script src="https://cdn.tailwindcss.com"\r',
//   '    title\r',
//   '        VPML - Example\r',
//   'html\r',
//   '    :macro !weird\r',
//   '        div | @1 works!\r',
//   '    !weird\r',
//   '        It does \r',
//   '    div | Does This Work?\r',
//   '    body w-full\r',
//   '        div navbar justify-center bg-base-300 sm:text-3xl text-5xl\r',
//   '            span sm:hidden\r',
//   '                VPML\r',
//   '            span hidden sm:block\r',
//   '                VPML - A Simple HTML Template Language\r',
//   '        div sm:container mx-auto py-4 sm:px-6 px-4 lg:max-w-[800px]\r',
//   '            h2 text-2xl md:text-3xl text-blue-300 mb-4\r',
//   '                Learn VPML\r',
//   '            p text-base md:text-lg text-gray-300\r',
//   '                VPML (Very Personal Markup Language) is a simple templating language that compiles into HTML. It uses indentation to determine element hierarchy. The language is meant to be flexible, predictable, and easy to read. The repo also comes with tooling for compiling and using General Preprocesser (GPP) to serve as a preprocessor for VPML files.\r',
//   '            div #syntax container mx-auto px-4 sm:px-6 lg:px-8 py-3\r',
//   '                h3 text-xl md:text-2xl text-blue-300 mb-3\r',
//   '                    Syntax\r',
//   '                ul list-disc pl-5 text-gray-400\r',
//   '# example of macro use\r',
//   '                    li li_tag\r',
//   "                        raw Tokens are delimited by spaces ' '.\r",
//   '                    li text-sm md:text-base\r',
//   "                        Newline '\\\\n' and carriage return '\\\\r' characters are stripped from tokens.\r",
//   '                    li text-sm md:text-base\r',
//   "                        raw Lines whose first token is a valid HTML tag name or first token starts with '<' are processed as HTML elements.\r",
//   '                    li text-sm md:text-base\r',
//   "                        raw If being processed as an element, if the first token ends with '>', it is considered as a self-closing tag.\r",
//   '                    li text-sm md:text-base\r',
//   "                        raw Tokens starting with '#' within a line are considered as part of the ID for the element.\r",
//   '                    li text-sm md:text-base\r',
//   "                        raw Tokens containing '=' within a line are processed as attributes with their respective values.\r",
//   '                    li text-sm md:text-base\r',
//   '                        raw Tokens that do not fit the rules for ID or attributes are assumed to be class names.\r',
//   '                    li text-sm md:text-base\r',
//   "                        raw Lines that do not start with a valid HTML tag or start with 'raw' are processed as text content.\r",
//   '                    li text-sm md:text-base\r',
//   "                        Comments are denoted by a line starting with '#'.\r",
//   '                    li text-sm md:text-base\r',
//   '                        raw If using GPP, you can define macros and use them within your VPML files. I recommend latex style macros.\r',
//   '            div #example container mx-auto px-4 sm:px-6 lg:px-8 py-5\r',
//   '                h3 text-xl md:text-2xl text-blue-300 mb-3\r',
//   '                    Example\r',
//   '                pre p-4 bg-gray-800 text-gray-300 whitespace-pre-wrap\r',
//   '                    raw head\r',
//   '                    raw   title\r',
//   '                    raw     VPML - Example\r',
//   '                    raw   link rel="stylesheet" href="styles.css"\r',
//   '                    raw html\r',
//   '                    raw # this is a comment\r',
//   '                    raw     body #body bg-black\r',
//   '                    raw         div #content bg-gray-800 #1\r',
//   '                    raw             h1 bg-blue\r',
//   '                    raw                 Hello World\r',
//   '                    raw             p\r',
//   '                    raw #           this is a comment\r',
//   '                    raw                 raw This is my site\r',
//   '                    raw         div #content bg-gray-800 #2\r',
//   '                    raw             h1 bg-blue\r',
//   '                    raw                 Hello World\r',
//   '                h3 text-xl md:text-2xl text-blue-300 mb-3\r',
//   '                    Output\r',
//   '# Comment\r',
//   '                pre p-4 bg-gray-800 text-gray-300 whitespace-pre-wrap\r',
//   '                    raw &lt head &gt\r',
//   '                    raw   &lt title &gt\r',
//   '                    raw     VPML - Example\r',
//   '                    raw   &lt / title &gt\r',
//   '                    raw   &lt link rel="stylesheet" href="styles.css" &gt\r',
//   '                    raw   &lt / link &gt\r',
//   '                    raw &lt / head &gt\r',
//   '                    raw &lt html &gt\r',
//   '                    raw     &lt body id="body" class="bg-black" &gt\r',
//   '                    raw         &lt div id="content1" class="bg-gray-800" &gt\r',
//   '                    raw             &lt h1 class="bg-blue" &gt\r',
//   '                    raw                 Hello World\r',
//   '                    raw             &lt / h1 &gt\r',
//   '                    raw             &lt p &gt\r',
//   '                    raw                 This is my site\r',
//   '                    raw             &lt / p &gt\r',
//   '                    raw         &lt / div &gt\r',
//   '                    raw         &lt div id="content2" class="bg-gray-800" &gt\r',
//   '                    raw             &lt h1 class="bg-blue" &gt\r',
//   '                    raw                 Hello World\r',
//   '                    raw             &lt / h1 &gt\r',
//   '                    raw         &lt / div &gt\r',
//   '                    raw     &lt / body &gt\r',
//   '                    raw &lt / html &gt\r',
//   '                    \r',
//   '            \r',
//   '            \r',
//   ... 3 more items
// ]

// %%
// l1 = "Hello World! @1 Hello carol@gmail.com"
// global_state["@1"] = new text_element("Hello World!", false);
// maybe_macros = l1.split("@")
// maybe_macros_names = maybe_macros.map((x) => x.split(" "))
// if(maybe_macros.length == 1){}
// for(li in maybe_macros_names){
//     for(ti in maybe_macros_names[li]){
//         if(("@" + maybe_macros_names[li][ti]) in global_state){
//             maybe_macros_names[li][ti] = "@" + global_state["@" + maybe_macros_names[li][ti]].text;
//         }
//     }
// }
// maybe_macros_names.map((x) => x.join(" ")).join("@").replaceAll("@@", "")

// %%
function indent_level(line){
    trimmed_len = line.trimStart().length
    if(trimmed_len == 0) return -1
    if(line[0] == "#") return -1
    return Math.trunc((line.length - trimmed_len) / 4)
}

function get_hierarchy(indent_levels){
    // int stack[count*2 + 1];
    stack = [];
    hierarchy = [];
    var cur_pos = -1;
    var prev_indent = -1;
    var cur_h_pos = 0;
    count = indent_levels.length;
    for(let i = 0; i < count; i++){
        let line_number = i;
        let current_indent = indent_levels[i];
        if(current_indent ==  -1){
            continue;
        }
        if(current_indent > prev_indent)
            stack[++cur_pos] = line_number;
        else if (current_indent <= prev_indent){
            while((cur_pos > -1) && (indent_levels[stack[cur_pos]] >= current_indent)){
                hierarchy[cur_h_pos++] = -1 * (stack[cur_pos--]);
            }
            stack[++cur_pos] = line_number;
        }
        hierarchy[cur_h_pos++] = (line_number);
        prev_indent = current_indent;
    }
    while(cur_pos > -1){
        hierarchy[cur_h_pos++] = -1 * (stack[cur_pos--]);
    }
    return hierarchy;
}

// %%
var root = new element();
current = root;
indent_levels = input.map(indent_level);
hierarchy = get_hierarchy(indent_levels);
for(ln of hierarchy){
    if(ln < 0){
        current = current.get_parent();
    }else{
        elem = process_line(input[ln]);
        // console.log("Line:" + input[ln]);
        // console.log("Forward: " + elem.forward());
        current.children.push(elem);
        elem.parent = current;
        current = elem;
    }
}
// Out:
// <ref *1> element {
//   children: [
//     tag_element {
//       children: [Array],
//       text: '',
//       parent: [Circular *1],
//       tag: 'head',
//       self_closing: false,
//       attributes: [],
//       classes: [],
//       id: '',
//       tokens: [Array],
//       line: 'head'
//     },
//     tag_element {
//       children: [Array],
//       text: '',
//       parent: [Circular *1],
//       tag: 'html',
//       self_closing: false,
//       attributes: [],
//       classes: [],
//       id: '',
//       tokens: [Array],
//       line: 'html'
//     }
//   ],
//   text: '',
//   parent: null
// }

// %%
function recurse(root){
    result = "";
    let forward = root.forward();
    for(child of root.get_children()){
        result += recurse(child);
    }
    return forward + result + root.backward();
}

// %%
fs.writeFileSync("index2.html", recurse(root), "utf-8");
